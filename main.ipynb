# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
first_img = cv.imread('assignment/Easy/29030.jpg', 0)

# %%
first_img.shape
# Out:
# (321, 481)

# %%
first_img_rgb = cv.cvtColor(first_img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(first_img_rgb)

# %%
# find frequency of pixels in range 0-255
histr = cv.calcHist([first_img_rgb],[0],None,[256],[0,256])

# %%
plt.plot(histr)

# %%
a = plt.hist(first_img_rgb.ravel(),256,[0,256])

# %%
equ = cv.equalizeHist(first_img)
# res = np.hstack((img,equ)) #stacking images side-by-side
# cv2.imwrite('res.png',res)

# %%
a = plt.hist(equ.ravel(),256,[0,256])

# %%
plt.imshow(first_img_rgb)

# %%
# equ = cv.cvtColor(equ, cv.COLOR_YUV2RGB)
plt.imshow(equ, cmap='gray')

# %%
res = np.hstack((first_img_rgb,equ)) #stacking images side-by-side
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 res = np.hstack((first_img_rgb,equ)) #stacking images side-by-side
#
# File ~/code/master/image/hw1/venv/lib/python3.10/site-packages/numpy/_core/shape_base.py:364, in hstack(tup, dtype, casting)
#     362     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     363 else:
# --> 364     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)
